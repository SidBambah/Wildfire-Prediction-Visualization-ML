# %% [markdown]
# ## Imports

# %%
import sqlite3
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Data Conversion

# %%
# Connecting to SQLITE database
db_path = '/content/gdrive/My Drive/Big Data Analytics/Data/wildfire_data.sqlite'
conn = sqlite3.connect(db_path)
c = conn.cursor()

# %%
# Extracting database table "fires" into Pandas table
table = pd.read_sql_query("SELECT * from fires", conn)

# %%
# Make sure it read successfully
table.head()
# Out:
#    OBJECTID  ...                                              Shape
# 0         1  ...  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1         2  ...  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2         3  ...  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3         4  ...  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4         5  ...  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
#
# [5 rows x 39 columns]

# %%
# Check the number of rows
len(table.index)
# Out:
# 1880465

# %%
# Saving Pandas Table into "fires_raw.csv" without any processing in case we need it
# in future
table.to_csv('/content/gdrive/My Drive/Big Data Analytics/Data/fires_raw.csv',
             index_label='index')

# %% [markdown]
# ## Data Processing

# %%
# Reading new csv into Pandas Dataframe for testing
firesDF = pd.read_csv("/content/gdrive/My Drive/Big Data Analytics/Data/fires_raw.csv",
                      low_memory=False)

# %%
# View the fields that are available
firesDF.head()
# Out:
#    index  ...                                              Shape
# 0      0  ...  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1      1  ...  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2      2  ...  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3      3  ...  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4      4  ...  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
#
# [5 rows x 40 columns]

# %%
# Convert date to an easily readable form
firesDF['DATE'] = pd.to_datetime(firesDF['DISCOVERY_DATE']
                                 - pd.Timestamp(0).to_julian_date(), unit='D')

# Check the changed data
firesDF.head()
# Out:
#    index  ...       DATE
# 0      0  ... 2005-02-02
# 1      1  ... 2004-05-12
# 2      2  ... 2004-05-31
# 3      3  ... 2004-06-28
# 4      4  ... 2004-06-28
#
# [5 rows x 41 columns]

# %%
# Add month and day of week
firesDF['MONTH'] = pd.DatetimeIndex(firesDF['DATE']).month
firesDF['DAY_OF_WEEK'] = firesDF['DATE'].dt.weekday_name
firesDF_orig = firesDF.copy()

# Check the changed data
firesDF.head()
# Out:
#    index  OBJECTID  FOD_ID  ...       DATE MONTH DAY_OF_WEEK
# 0      0         1       1  ... 2005-02-02     2   Wednesday
# 1      1         2       2  ... 2004-05-12     5   Wednesday
# 2      2         3       3  ... 2004-05-31     5      Monday
# 3      3         4       4  ... 2004-06-28     6      Monday
# 4      4         5       5  ... 2004-06-28     6      Monday
#
# [5 rows x 43 columns]

# %%
# Generate a new csv that will be put in MongoDB for webapp
firesDF.to_csv("/content/gdrive/My Drive/Big Data Analytics/Data/fires_processed.csv",
               header=True)
